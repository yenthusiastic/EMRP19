# %% [markdown]
# ### moers_bins_v04.ipynb
#
#
#
# The content of this Notebook is based on [this](https://automating-gis-processes.github.io/2017/course-info/course-info.html) course from the University of Helsinki.
#
# And the [this](https://mlrose.readthedocs.io/en/stable/source/tutorial2.html) tutorial for solving the Travelling Salesman Problem with `mlrose`.

# %%
import mlrose
import numpy as np
import geopandas as gpd
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
from geopandas.tools import geocode
from itertools import chain
from shapely.geometry import LineString, Point
# Out:
# C:\Users\sarah\Anaconda3\envs\geo_py_37\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %% [markdown]
# ### Import street network of Moers from OpenStreetMaps
# #### network_type='bike' or 'drive' or 'walk'

# %%
place_name = "Moers, Germany"
graph = ox.graph_from_place(place_name, network_type='drive')
#ox.save_load.save_graph_shapefile(graph, "Moers", folder="Data/")

# %%
#ox.save_load.save_as_osm(graph, "Moers", folder="Data/")

# %%
nodes, edges = ox.graph_to_gdfs(graph, nodes=True, edges=True)

# %%
nodes.crs
# Out:
# '+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs'

# %% [markdown]
# ### Geocode the starting point (ENNI Betriebshof)

# %%
# Geocode addresses with Nominatim backend
start = geocode("Am Jostenhof 7-9, 47441 Moers, Germany", provider='nominatim')
start.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %% [markdown]
# ### Import shapefile (created with QGIS) of bins in Moers

# %%
fp = "Data/bins_Moers.shp"
bins = gpd.read_file(fp)
bins.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# ### Reproject the points to the same projection as the road network

# %%
proj_text = str.format(edges.crs)

# Reproject the geometries by replacing the values with projected ones
bins = bins.to_crs(proj_text)
#end_point = points_proj.iloc[np.argmin(distances)]
#data_bin_proj.crs = CRS("EPSG:32632")
start = start.to_crs(proj_text)
# Out:
# C:\Users\sarah\Anaconda3\envs\geo_py_37\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\sarah\Anaconda3\envs\geo_py_37\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### Reformat start point

# %%
start_point = start.geometry
start_xy = (start_point.y.item(), start_point.x.item())

# %% [markdown]
# ### Sample 10 "full" bins

# %%
sample_bin = bins.sample(n=10)
sample_bin.head()
# Out:
#                      Name   Latitude  Longitude  lfd# Nr# Stadtteil  \
# 792  Papierkorb 200000345  51.450012   6.636678      1931      None
# 960  Papierkorb 200000227  51.440839   6.662252      2099      None
# 467  Papierkorb 200000038  51.489818   6.602016      1606      None
# 336  Papierkorb 200000150  51.451579   6.626141      1475      None
# 607  Papierkorb 200000023  51.484190   6.616093      1746      None
#
#      Anzahl_beh    ort Straße         Art Abfuhrtag Woche-g-ug Telefon  \
# 792           1  Moers   None  Papierkorb      None       None    None
# 960           1  Moers   None  Papierkorb      None       None    None
# 467           1  Moers   None  Papierkorb      None       None    None
# 336           1  Moers   None  Papierkorb      None       None    None
# 607           1  Moers   None  Papierkorb      None       None    None
#
#      Zeitbedarf                  geometry
# 792         0.5  POINT (6.63668 51.45001)
# 960         0.5  POINT (6.66225 51.44084)
# 467         0.5  POINT (6.60202 51.48982)
# 336         0.5  POINT (6.62614 51.45158)
# 607         0.5  POINT (6.61609 51.48419)

# %%
sample_points = sample_bin.geometry

# %%
sample_points
# Out:
# 792    POINT (6.63668 51.45001)
# 960    POINT (6.66225 51.44084)
# 467    POINT (6.60202 51.48982)
# 336    POINT (6.62614 51.45158)
# 607    POINT (6.61609 51.48419)
# 64     POINT (6.60037 51.41375)
# 780    POINT (6.63770 51.45084)
# 136    POINT (6.59450 51.41774)
# 32     POINT (6.60017 51.40489)
# 327    POINT (6.62758 51.45245)
# Name: geometry, dtype: geometry

# %%
sample_xy = []

# %% [markdown]
# ### Add start point to bin samples

# %%
sample_xy.append(start_xy)

# %%
sample_xy
# Out:
# [(51.4525429, 6.607198265428346)]

# %% [markdown]
# ### Reformat points of "full" bins

# %%
for index in range(0,sample_points.count()):
    sample_xy.append((sample_points.iloc[index].y, sample_points.iloc[index].x))

# %%
print(sample_xy)
# Out:
# [(51.4525429, 6.607198265428346), (51.45001179, 6.636677524), (51.44083888, 6.662252303), (51.48981811, 6.602016008), (51.45157937, 6.626141053), (51.48419009, 6.616092995), (51.4137469, 6.600369047), (51.45083824, 6.63769735), (51.4177392, 6.594498111), (51.40488815, 6.60016587), (51.45245017, 6.627576705)]

# %% [markdown]
# #### Initialize fitness function object by using a list coordinates (sample_x_y)

# %%
fitness_coords = mlrose.TravellingSales(coords = sample_xy)

# %% [markdown]
# #### Define optimization problem object

# %%
problem_fit = mlrose.TSPOpt(length = len(sample_xy), fitness_fn = fitness_coords, maximize=False)

# %%
# Solve problem using the genetic algorithm
best_state, best_fitness, fitness_curve = mlrose.genetic_alg(problem_fit, mutation_prob = 0.2, max_attempts = 50, random_state = 2, curve = True)

print(best_state)
print(best_fitness)
# Out:
# [10  5  3  0  8  6  9  4  7  2  1]
# 0.2676718131580615

# %%
#print(fitness_curve)

# %% [markdown]
# ### Calculate the network nodes that are closest to start and end point

# %%
orig_xy = sample_xy[best_state[0]]
target_xy = sample_xy[best_state[1]]

orig_node = ox.get_nearest_node(graph, orig_xy, method='euclidean')
target_node = ox.get_nearest_node(graph, target_xy, method='euclidean')

print(orig_node)
print(target_node)
# Out:
# 80163536
# 4391953556

# %%
route = []

# %%
#route = nx.shortest_path(G=graph, source=orig_node, target=target_node, weight='length')

# %%
#fig, ax = ox.plot_graph_route(graph, route, origin_point=orig_xy, destination_point=target_xy, show=False, close=False)

#sample_bin.plot(ax=ax, color='red', markersize=5)

#plt.tight_layout()

# %%
for index in range(0,sample_points.count()+1):
    
    if index == int(sample_points.count()):
        orig_xy = sample_xy[best_state[-1]]
        target_xy = sample_xy[best_state[0]]
        print("!!!")
        
    else:
    
        orig_xy = sample_xy[best_state[index]]
        target_xy = sample_xy[best_state[index+1]]
    
    orig_node = ox.get_nearest_node(graph, orig_xy, method='euclidean')
    target_node = ox.get_nearest_node(graph, target_xy, method='euclidean')
    
    #print(orig_node)
    #print(target_node)
    
    route_temp = nx.shortest_path(G=graph, source=orig_node, target=target_node, weight='length')
    print(route)
    route.append(route_temp)
    route_temp = []
# Out:
# []
694240, 266739124, 266739005, 266739003, 122268712, 26111382, 26111385, 26111387, 26339162, 25811679, 25811677, 25811676, 26111348, 1446573613, 25750008, 26597883, 25734781, 26111345, 26139084, 25811675, 25811674, 26931462, 2304466234], [2304466234, 26931462, 25811674, 25811675, 26139084, 26111345, 25734781, 25734782, 26139663, 25734219, 25734791, 25734133, 25734790, 25734358, 26298361, 26111411], [26111411, 1780626394, 1905608695, 25734337, 1905614710, 2864665467, 1918595156, 25719982, 25734114, 25766507, 25734377, 25734443, 3117022926, 3117022933, 3674900041, 3674900032, 3674900039, 25734509, 1906169855, 3822460370, 1906166324, 1931264450, 1931264449, 3014547977, 25734639, 25734641, 4381988396, 25734665], [25734665, 4381988396, 25734641, 25734639, 3014547977, 1931264449, 1931264450, 1906166324, 3822460383, 1906169855, 25734509, 3674900039, 25734481, 3674900041, 3117022933, 3117022940, 25734443, 25734377, 25766507, 25734114, 25719982, 1918595156, 2864665467, 1905614710, 25734337, 25734358]]

# %%
fig, ax = ox.plot_graph_routes(graph, route, save=True, show=False, close=False)

sample_bin.plot(ax=ax, color='blue', markersize=100)

plt.tight_layout()

# %% [markdown]
# ### Combine the nodes of the route with information from the network

# %%
route_nodes = nodes.loc[list(chain(*route))]

# %%
print(route_nodes)
# Out:
#                     y         x       osmid highway  ref  \
# 80163536    51.452992  6.627839    80163536     NaN  NaN
# 25811669    51.452565  6.628237    25811669     NaN  NaN
# 2168976894  51.452759  6.628118  2168976894     NaN  NaN
# 2168976908  51.453256  6.627923  2168976908     NaN  NaN
# 2168976911  51.453344  6.627915  2168976911     NaN  NaN
# ...               ...       ...         ...     ...  ...
# 80163533    51.453322  6.628719    80163533     NaN  NaN
# 2168976911  51.453344  6.627915  2168976911     NaN  NaN
# 25811668    51.453336  6.627771    25811668     NaN  NaN
# 656649108   51.453246  6.627765   656649108     NaN  NaN
# 80163536    51.452992  6.627839    80163536     NaN  NaN
#
#                             geometry
# 80163536    POINT (6.62784 51.45299)
# 25811669    POINT (6.62824 51.45257)
# 2168976894  POINT (6.62812 51.45276)
# 2168976908  POINT (6.62792 51.45326)
# 2168976911  POINT (6.62791 51.45334)
# ...                              ...
# 80163533    POINT (6.62872 51.45332)
# 2168976911  POINT (6.62791 51.45334)
# 25811668    POINT (6.62777 51.45334)
# 656649108   POINT (6.62776 51.45325)
# 80163536    POINT (6.62784 51.45299)
#
# [296 rows x 6 columns]

# %% [markdown]
# ### Convert route into a linestring

# %%
route_line = LineString(list(route_nodes.geometry.values))
print(route_line)
# Out:
# LINESTRING (6.627839 51.4529916, 6.6282367 51.4525653, 6.6281177 51.452759, 6.6279229 51.4532562, 6.6279149 51.4533439, 6.6280527 51.4538162, 6.6281772 51.4540597, 6.6286494 51.4549036, 6.6290448 51.4556113, 6.6293605 51.4566266, 6.6297964 51.4584825, 6.6302524 51.4605238, 6.6306479 51.4616123, 6.6306961 51.4616438, 6.6313955 51.4619493, 6.631268 51.4620551, 6.630777 51.4633077, 6.6307887 51.4634343, 6.6310279 51.4660249, 6.6312592 51.4684593, 6.6314981 51.4706197, 6.6315064 51
5980316 51.4082103, 6.5987632 51.4076943, 6.5990276 51.4073988, 6.5992654 51.407084, 6.599516 51.4066784, 6.599897 51.4060514, 6.599475 51.4058915, 6.5996 51.4054706, 6.5996232 51.4053914, 6.599812 51.4054132, 6.5999056 51.4051352, 6.5999056 51.4051352, 6.599812 51.4054132, 6.5996232 51.4053914, 6.5996 51.4054706, 6.599475 51.4058915, 6.599897 51.4060514, 6.599516 51.4066784, 6.5992654 51.407084, 6.5990276 51.4073988, 6.5987632 51.4076943, 6.5980316 51.4082103, 6.5991363 51.4087937, 6.5996666 51.4090638, 6.5993502 51.409399, 6.5990361 51.4097527, 6.5985839 51.4100721, 6.5980274 51.4104856, 6.5982465 51.4105971, 6.595408 51.4128396, 6.5950681 51.4132833, 6.5943233 51.4148494, 6.5955499 51.4148844, 6.5964112 51.416969, 6.5971796 51.418043, 6.5975432 51.4180719, 6.6002486 51.4187228, 6.6006018 51.4188088, 6.6019171 51.4191211, 6.6026073 51.4193156, 6.6 ...

# %% [markdown]
# ### Create a GeoDataFrame from the linestring

# %%
route_geom = gpd.GeoDataFrame(crs=edges.crs)

route_geom['geometry'] = None
route_geom['osmids'] = None

# %%
route_geom.loc[0, 'geometry'] = route_line

route_geom.loc[0, 'osmids'] = str(list(route_nodes['osmid'].values))

# %% [markdown]
# ### Plot the route s dashed line onto the nodes and edges of the network

# %%
fig, ax = plt.subplots()
edges.plot(ax=ax, linewidth=0.75, color='gray')
nodes.plot(ax=ax, markersize=2, color='gray')
route_geom.plot(ax=ax, linewidth=4, linestyle='--', color='red')
plt.tight_layout()

# %% [markdown]
# ### Prepare the saving of shapefiles

# %%
place_name_out = place_name.replace(' ', '_').replace(',','')
#streets_out = r"Data/%s_streets.shp" % place_name_out
route_out = r"Data/Route_%s.shp" % place_name_out

# %%
#edges.to_file(streets_out)

# %%
route_geom.to_file(route_out)

# %%
route
# Out:
# [[80163536,
#   25811669,
#   2168976894,
#   2168976908,
#   2168976911,
#   2168976917,
#   2168976925,
#   25811665,
#   25811664,
#   25811662,
#   60200049,
#   26308055,
#   1299517688,
#   1299517687,
#   26111418,
#   1299524632,
#   26881392,
#   1299528863,
#   26881229,
#   26881236,
#   26111421,
#   7136746905,
#   1299698293,
#   2926579421,
#   2926579427,
#   26881253,
#   379049731,
#   26881261,
#   26111426,
#   26111428,
#   26111427,
#   254189262,
#   1351332285,
#   26111431,
#   1351332586,
#   254189167,
#   253179377,
#   253178517,
#   4391953556],
#  [4391953556,
#   253178517,
#   253178514,
#   253178513,
#   253178757,
#   253178509,
#   253178194,
#   253178392,
#   253178068,
#   253177590,
#   253176538,
#   26881317,
#   253176061,
#   26881320,
#   253049433,
#   253139561,
#   212780626,
#   26881328,
#   253048853,
#   242693907,
#   253137189],
#  [253137189,
#   242693907,
#   242693909,
#   253048872,
#   4142577898,
#   247833363,
#   253048864,
#   250063721,
#   247833359,
#   253047259,
#   1552000585,
#   1552000548,
#   1552000532,
#   28248582,
#   28248588,
#   2051670620,
#   28245122,
#   28245119,
#   4463130354,
#   26111507,
#   4428750287,
#   4463116154,
